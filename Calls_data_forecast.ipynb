# %% [markdown]
# <a href="https://colab.research.google.com/github/sivaram1966/Centralized-and-Decentralized-Supply-Chain-Planning/blob/main/Calls_data_forecast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## This code containts forecasts using time series methods (ES and AR) and ML methods (tree ensembles using GB and XGB) for Calls Data

# %%
# Commonly used python functions and display settings



# conda -c -forge
# conda  -c-forge

# !pip install pmdarima
# !pip install statsmodels
# !pip install xgboost
# !pip install scikit-learn
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:,.2f}'.format

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython.display import display, HTML

import warnings
warnings.filterwarnings("ignore") # specify to ignore warning messages
# Out:
# Requirement already satisfied: pmdarima in c:\users\lenovo\anaconda3.2\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pmdarima) (3.1.2)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pmdarima) (1.5.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pmdarima) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pmdarima) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pmdarima) (75.1.0)
# Requirement already satisfied: packaging>=17.1 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pmdarima) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lenovo\anaconda3.2\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\lenovo\anaconda3.2\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in c:\users\lenovo\anaconda3.2\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Requirement already satisfied: statsmodels in c:\users\lenovo\anaconda3.2\lib\site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\lenovo\anaconda3.2\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\lenovo\anaconda3.2\lib\site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\lenovo\anaconda3.2\lib\site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\lenovo\anaconda3.2\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\lenovo\anaconda3.2\lib\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3.2\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in c:\users\lenovo\anaconda3.2\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Requirement already satisfied: xgboost in c:\users\lenovo\anaconda3.2\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3.2\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3.2\lib\site-packages (from xgboost) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\anaconda3.2\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\lenovo\anaconda3.2\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\lenovo\anaconda3.2\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lenovo\anaconda3.2\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lenovo\anaconda3.2\lib\site-packages (from scikit-learn) (3.5.0)

# %%
# Key imports for this code (various ML and Stat Models)


from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.api import ExponentialSmoothing
from statsmodels.tsa.statespace.sarimax import SARIMAX
import statsmodels.api as sm
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.stattools import pacf
import pmdarima as pm
from pmdarima import model_selection
from pmdarima import auto_arima

# %%
# import viz libraries
import matplotlib.pyplot as plt
import plotly
plotly.offline.init_notebook_mode(connected=True)
from plotly.graph_objs import *
from plotly import tools
import plotly.graph_objects as go
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Preliminary Data Analysis

# %%
# fetch data from the CSV file
calls_df = pd.read_csv('C:\Users\Lenovo\Desktop\calls_data.csv', parse_dates = ['date'])

# The next 2 lines give the first 5 lines of the CSV file and the last 5 lines
calls_df.head()
calls_df.tail()
# Out:
#   Cell In[87], line 2
#     calls_df = pd.read_csv('C:\Users\Lenovo\Desktop\calls_data.csv', parse_dates = ['date'])
#                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# fetch data from the CSV file
# Fix: Removed the \r characters that were incorrectly added to the path
# Use either double backslashes or a raw string (r prefix) for Windows paths
calls_df = pd.read_csv(r'C:\Users\Lenovo\Desktop\calls_data.csv', parse_dates=['date'])

# The next 2 lines give the first 5 lines of the CSV file and the last 5 lines
calls_df.head()
calls_df.tail()
# Out:
#         date  calls
# 0 1979-01-31 116.63
# 1 1979-02-28 100.80
# 2 1979-03-31 106.82
# 3 1979-04-30 103.49
# 4 1979-05-31  91.76
#           date  calls
# 475 2018-08-31 222.64
# 476 2018-09-30 186.75
# 477 2018-10-31 201.84
# 478 2018-11-30 182.68
# 479 2018-12-31 243.19

# %% [markdown]
# The issue was that your path had `\r` characters which are interpreted as carriage returns in Python strings. I've corrected it by:
# 1. Using the correct path you provided
# 2. Using a raw string (r prefix) to avoid escape character interpretation

# %%
# Creating a plot of calls made over time
plot_data = []
plot_data.append(go.Scatter(x= calls_df['date'], y= calls_df['calls']))
layout = go.Layout(xaxis = dict(title='Date'), yaxis = dict(title= 'Calls Made'),
                   title = 'Time Series of Monthly Calls Made')
fig = go.Figure(data= plot_data, layout=layout)

plotly.offline.iplot(fig)

# %%
# Zooming into the 100th to 119th data points of above plot
plot_data = []
plot_data.append(go.Scatter(x= calls_df['date'][100:120], y= calls_df['calls'][100:120]))
layout = go.Layout(xaxis = dict(title='Date'), yaxis = dict(title= 'Calls Made'),
                   title = 'Time Series of Monthly Calls Made')
fig = go.Figure(data= plot_data, layout=layout)

plotly.offline.iplot(fig)

# %%
# Representing above plot using dots
plot_data = []
plot_data.append(go.Scatter(x= calls_df['date'][100:120], y= calls_df['calls'][100:120], mode = 'markers'))
layout = go.Layout(xaxis = dict(title='Date'), yaxis = dict(title= 'Calls Made'),
                   title = 'Time Series of Monthly Calls Made')
fig = go.Figure(data= plot_data, layout=layout)

plotly.offline.iplot(fig)

# %%
# This creates a graph of the autocorrelation function versus lags for the calls data
sm.graphics.tsa.plot_acf(calls_df['calls'].values.squeeze(), lags=40)

# %%
# This creates a graph of the partial autocorrelation function versus lags for the calls data
sm.graphics.tsa.plot_pacf(calls_df['calls'].values.squeeze(), lags=40)

# %%
# subset data to only include 300 data points (most recent)
# ES and ARIMA methods are better with < 200 training data points

subset_data = calls_df[calls_df['date'] > '1994-01-01'].reset_index(drop = True)
len(subset_data)
subset_data.head()
subset_data.isna().sum()
# Out:
# 300
#         date  calls
# 0 1994-01-31 160.05
# 1 1994-02-28 163.15
# 2 1994-03-31 173.05
# 3 1994-04-30 158.49
# 4 1994-05-31 162.24
# date     0
# calls    0
# dtype: int64

# %% [markdown]
# ## Exponential Smoothing

# %%
# First we get the time series
time_series = subset_data['calls']

# Define the seasonal periods
seasonal_periods = 12

# Define the number of predictions to make
h = 1

# Define the length of each training set
T = 200

# Initialize the lists to store the percentage and absolute errors
perc_error_list = []
abs_error_list = []

es_preds_train = np.zeros(T+h) # In case we wish to use the ES predictions

# Loop through the data frame and make predictions using exponential smoothing
for i in range(len(time_series) - T - h):
    # Define the training and testing data sets
    train = time_series.iloc[i:i+T].values
    test = time_series.iloc[i+T:i+T+h].values

    # Fit the exponential smoothing model
    model = ExponentialSmoothing(train, trend='add', seasonal='add', seasonal_periods=seasonal_periods)
    fit_model = model.fit()

    # Make predictions
    pred_list = fit_model.forecast(h)
    preds = pred_list[h-1]

    # Calculate percentage and absolute errors
    perc_errors = np.abs(test[h-1]-preds)/test[h-1]
    abs_errors = np.abs(test[h-1]-preds)

    # Store the percentage and absolute errors
    perc_error_list.append(perc_errors)
    abs_error_list.append(abs_errors)

    # Get the ES predictions
    es_preds_train = np.append(es_preds_train, preds)

# %%
# Print the percentage-error results
print('Mean absolute percentage error:', np.mean(perc_error_list, axis = 0))
print('Median absolute percentage error:', np.median(perc_error_list, axis = 0))
print('75th percentile of absolute percentage error:', np.percentile(perc_error_list, 75, axis = 0))
print('90th percentile of absolute percentage error:', np.percentile(perc_error_list, 90, axis = 0))
# Out:
# Mean absolute percentage error: 0.05685818161827286
# Median absolute percentage error: 0.048116448010056455
# 75th percentile of absolute percentage error: 0.08422095742476457
# 90th percentile of absolute percentage error: 0.11024629453423335

# %%
# Print the absolute error ratio results
avg_global = subset_data['calls'][T+h:].mean()
print('Mean absolute error ratio:', np.mean(abs_error_list, axis = 0)/avg_global)
print('Median absolute error ratio:', np.median(abs_error_list, axis = 0)/avg_global)
print('75th percentile absolute error ratio:', np.percentile(abs_error_list, 75, axis = 0)/avg_global)
print('90th percentile absolute error ratio:', np.percentile(abs_error_list, 90, axis = 0)/avg_global)
# Out:
# Mean absolute error ratio: 0.054998096348507323
# Median absolute error ratio: 0.050643627210308836
# 75th percentile absolute error ratio: 0.08170706264998498
# 90th percentile absolute error ratio: 0.11706453171215149

# %% [markdown]
# ## SARIMAX initial model building and then train & predict

# %%
# Getting optimal differencing
d_opt = pm.arima.ndiffs(subset_data['calls'].iloc[0:T])
d_opt
D_opt = pm.arima.nsdiffs(subset_data['calls'].iloc[0:T], m = seasonal_periods)
D_opt
# Out:
# 1
# 0

# %%
# Graphical study of the effect of differencing
subset_data['diff1'] = subset_data['calls'] - subset_data['calls'].shift(periods = 1)
subset_data['diff2'] = subset_data['diff1'] - subset_data['diff1'].shift(periods = 1)
subset_data.head()

sm.graphics.tsa.plot_acf(subset_data['calls'].values.squeeze(), lags=40)
sm.graphics.tsa.plot_acf(subset_data['diff1'].dropna().values.squeeze(), lags=40)
sm.graphics.tsa.plot_acf(subset_data['diff2'].dropna().values.squeeze(), lags=40)
# Out:
#         date  calls  diff1  diff2
# 0 1994-01-31 160.05    NaN    NaN
# 1 1994-02-28 163.15   3.10    NaN
# 2 1994-03-31 173.05   9.89   6.80
# 3 1994-04-30 158.49 -14.56 -24.46
# 4 1994-05-31 162.24   3.76  18.32

# %%
# That we just to show, now we need to remove the columns we created in the previous cell
subset_data.drop(columns = ['diff1', 'diff2'], inplace = True)
subset_data.head()
# Out:
#         date  calls
# 0 1994-01-31 160.05
# 1 1994-02-28 163.15
# 2 1994-03-31 173.05
# 3 1994-04-30 158.49
# 4 1994-05-31 162.24

# %%
# Initialize the lists to store the percentage and absolute errors
ar_perc_error_list = []
ar_abs_error_list = []

ar_preds_train = np.zeros(T+h) # In case we wish to use the ARIMA predictions

# Loop through the data frame and make predictions using ARIMA
for i in range(len(time_series) - T - h):
    # Define the training and testing data sets
    train = time_series.iloc[i:i+T].values
    test = time_series.iloc[i+T:i+T+h].values

    # Using a specified order (this would need to be fine-tuned)
    order = (1, 1, 0)
    seasonal_order = (1, 0, 0, seasonal_periods)

    # Fit the SARIMAX or ARIMA model
    model = SARIMAX(endog=train, exog=None, order=order, seasonal_order=seasonal_order)
    fit_model = model.fit(disp=False)

    # Make predictions
    pred_list = fit_model.forecast(steps=len(test), exog=None)
    preds = pred_list[h-1]

    # Calculate percentage and absolute errors
    ar_perc_errors = np.abs(test[h-1]-preds)/test[h-1]
    ar_abs_errors = np.abs(test[h-1]-preds)

    # Store the percentage and absolute errors
    ar_perc_error_list.append(ar_perc_errors)
    ar_abs_error_list.append(ar_abs_errors)

    # Get the ARIMA predictions
    ar_preds_train = np.append(ar_preds_train, preds)

# %%
# Print the percentage-error results
print('Mean absolute percentage error:', np.mean(ar_perc_error_list, axis = 0))
print('Median absolute percentage error:', np.median(ar_perc_error_list, axis = 0))
print('75th percentile of absolute percentage error:', np.percentile(ar_perc_error_list, 75, axis = 0))
print('90th percentile of absolute percentage error:', np.percentile(ar_perc_error_list, 90, axis = 0))
# Out:
# Mean absolute percentage error: 0.08358052504494326
# Median absolute percentage error: 0.07581434142193487
# 75th percentile of absolute percentage error: 0.12954856641205048
# 90th percentile of absolute percentage error: 0.15938018724597794

# %%
# Print the absolute error ratio results
print('Mean absolute error ratio:', np.mean(ar_abs_error_list, axis = 0)/avg_global)
print('Median absolute error ratio:', np.median(ar_abs_error_list, axis = 0)/avg_global)
print('75th percentile absolute error ratio:', np.percentile(ar_abs_error_list, 75, axis = 0)/avg_global)
print('90th percentile absolute error ratio:', np.percentile(ar_abs_error_list, 90, axis = 0)/avg_global)
# Out:
# Mean absolute error ratio: 0.08212696989531922
# Median absolute error ratio: 0.07483856593992509
# 75th percentile absolute error ratio: 0.12624973792204475
# 90th percentile absolute error ratio: 0.16153553174457816

# %% [markdown]
# ### For Gradient Boosting we first do some trend adjustment

# %%
# For the ML Models we use the dates to obtain the month and year as features
subset_data['month'] = subset_data['date'].dt.month
subset_data['year'] = subset_data['date'].dt.year
subset_data.head()
subset_data.tail()
# Out:
#         date  calls  month  year
# 0 1994-01-31 160.05      1  1994
# 1 1994-02-28 163.15      2  1994
# 2 1994-03-31 173.05      3  1994
# 3 1994-04-30 158.49      4  1994
# 4 1994-05-31 162.24      5  1994
#           date  calls  month  year
# 295 2018-08-31 222.64      8  2018
# 296 2018-09-30 186.75      9  2018
# 297 2018-10-31 201.84     10  2018
# 298 2018-11-30 182.68     11  2018
# 299 2018-12-31 243.19     12  2018

# %%
# To get the trend, we average across all months of a year (using only training data)
yearly_avg = subset_data[['calls', 'year']].iloc[0:T].groupby(['year']).mean()
yearly_avg
# Out:
#       calls
# year
# 1994 177.71
# 1995 172.41
# 1996 172.13
# 1997 171.18
# 1998 182.82
# 1999 175.21
# 2000 186.32
# 2001 182.51
# 2002 182.89
# 2003 185.03
# 2004 185.68
# 2005 188.41
# 2006 195.72
# 2007 188.46
# 2008 189.29
# 2009 196.72
# 2010 197.70

# %%
# We can bring the year back as a feature (above it is in the index, so we reset it)
yearly_avg.reset_index(inplace = True)

# %%
# Regression model to fit a linear trend model

model = LinearRegression(fit_intercept = True)
model.fit(yearly_avg['year'].array.reshape(-1, 1), yearly_avg['calls']) # When extending to multiple features remove .array.reshape(-1, 1)

# The following gives the R-square score
model.score(yearly_avg['year'].array.reshape(-1, 1), yearly_avg['calls'])

# This is the coefficient Beta_1 (or slope of the Simple Linear Regression line)
model.coef_

# This is the coefficient Beta_0
model.intercept_
# Out:
# LinearRegression()
# 0.8160847605223521
# array([1.49954221])
# -2817.9546858574363

# %%
# Applying the trend for the test and train dataset across all months
subset_data['trend'] = -2817.955 + 1.4995*(subset_data['year']+subset_data['month']/12)
subset_data.head()
# Out:
#         date  calls  month  year  trend
# 0 1994-01-31 160.05      1  1994 172.17
# 1 1994-02-28 163.15      2  1994 172.30
# 2 1994-03-31 173.05      3  1994 172.42
# 3 1994-04-30 158.49      4  1994 172.55
# 4 1994-05-31 162.24      5  1994 172.67

# %%
# Plotting the trend line (regression line) along with the monthly calls data
plot_data = []
plot_data.append(go.Scatter(x= subset_data['date'], y= subset_data['calls'], name = 'calls'))
plot_data.append(go.Scatter(x= subset_data['date'], y= subset_data['trend'], name = 'trend'))
layout = go.Layout(xaxis = dict(title='Date'), yaxis = dict(title= 'Calls Made and Trend'),
                   title = 'Time Series of Monthly Calls Made with Trend')
fig = go.Figure(data= plot_data, layout=layout)

plotly.offline.iplot(fig)

# %%
# To get some of the lag features later we would need the full data set, and extract the date and year; trend
calls_df['month'] = calls_df['date'].dt.month
calls_df['year'] = calls_df['date'].dt.year
calls_df['trend'] = -2817.955 + 1.4995*(calls_df['year']+calls_df['month']/12)

# %%
# Residuals (de-trending) and shifting them to get lags by 1 month and 12 months
subset_data['resid_lags'] = (calls_df['calls']-calls_df['trend']).shift(periods =
                                                seasonal_periods)[-len(subset_data):].reset_index(drop = True)
subset_data['resid_lag1'] = (calls_df['calls']-calls_df['trend']).shift(periods =
                                                        1)[-len(subset_data):].reset_index(drop = True)
subset_data.head(15)
subset_data.tail()
# Out:
#          date  calls  month  year  trend  resid_lags  resid_lag1
# 0  1994-01-31 160.05      1  1994 172.17       -9.96        7.11
# 1  1994-02-28 163.15      2  1994 172.30      -34.48      -12.12
# 2  1994-03-31 173.05      3  1994 172.42       -8.11       -9.14
# 3  1994-04-30 158.49      4  1994 172.55      -28.58        0.63
# 4  1994-05-31 162.24      5  1994 172.67      -18.62      -14.06
# 5  1994-06-30 203.78      6  1994 172.80       33.04      -10.43
# 6  1994-07-31 210.04      7  1994 172.92       22.47       30.98
# 7  1994-08-31 188.81      8  1994 173.05       42.73       37.11
# 8  1994-09-30 161.82      9  1994 173.17      -20.27       15.76
# 9  1994-10-31 178.58     10  1994 173.30       -5.12      -11.35
# 10 1994-11-30 164.16     11  1994 173.42      -33.17        5.28
# 11 1994-12-31 208.37     12  1994 173.55        7.11       -9.26
# 12 1995-01-31 145.97      1  1995 173.67      -12.12       34.83
# 13 1995-02-28 144.28      2  1995 173.80       -9.14      -27.70
# 14 1995-03-31 165.78      3  1995 173.92        0.63      -29.51
#           date  calls  month  year  trend  resid_lags  resid_lag1
# 295 2018-08-31 222.64      8  2018 209.04       17.64       25.41
# 296 2018-09-30 186.75      9  2018 209.16        7.93       13.60
# 297 2018-10-31 201.84     10  2018 209.29       -8.42      -22.41
# 298 2018-11-30 182.68     11  2018 209.41      -16.32       -7.44
# 299 2018-12-31 243.19     12  2018 209.54       18.07      -26.73

# %%
# Obtaining the training data (note: unlike ES and ARIMA, here we do not retrain)
X_train = subset_data[0:T]
X_train['residual'] = X_train['calls'] - X_train['trend']
X_train.head()
X_train.tail()
# The "y" variable that we predict is the residual itself
y_train = X_train['residual']
y_train
# Out:
#         date  calls  month  year  trend  resid_lags  resid_lag1  residual
# 0 1994-01-31 160.05      1  1994 172.17       -9.96        7.11    -12.12
# 1 1994-02-28 163.15      2  1994 172.30      -34.48      -12.12     -9.14
# 2 1994-03-31 173.05      3  1994 172.42       -8.11       -9.14      0.63
# 3 1994-04-30 158.49      4  1994 172.55      -28.58        0.63    -14.06
# 4 1994-05-31 162.24      5  1994 172.67      -18.62      -14.06    -10.43
#           date  calls  month  year  trend  resid_lags  resid_lag1  residual
# 195 2010-04-30 172.89      4  2010 196.54      -16.91       -7.49    -23.65
# 196 2010-05-31 188.69      5  2010 196.66       -4.54      -23.65     -7.97
# 197 2010-06-30 213.24      6  2010 196.79       24.75       -7.97     16.45
# 198 2010-07-31 221.73      7  2010 196.91       37.84       16.45     24.81
# 199 2010-08-31 217.57      8  2010 197.04       17.43       24.81     20.53
# 0     -12.12
# 1      -9.14
# 2       0.63
# 3     -14.06
# 4     -10.43
#        ...
# 195   -23.65
# 196    -7.97
# 197    16.45
# 198    24.81
# 199    20.53
# Name: residual, Length: 200, dtype: float64

# %%
# The remaining 100 data points are test data
X_test = subset_data[T:]
X_test.head()
X_test.tail()
# Out:
#           date  calls  month  year  trend  resid_lags  resid_lag1
# 200 2010-09-30 192.99      9  2010 197.16      -21.12       20.53
# 201 2010-10-31 168.57     10  2010 197.29      -11.96       -4.18
# 202 2010-11-30 180.52     11  2010 197.41       13.19      -28.72
# 203 2010-12-31 227.85     12  2010 197.54       28.36      -16.90
# 204 2011-01-31 167.04      1  2011 197.66       -8.77       30.31
#           date  calls  month  year  trend  resid_lags  resid_lag1
# 295 2018-08-31 222.64      8  2018 209.04       17.64       25.41
# 296 2018-09-30 186.75      9  2018 209.16        7.93       13.60
# 297 2018-10-31 201.84     10  2018 209.29       -8.42      -22.41
# 298 2018-11-30 182.68     11  2018 209.41      -16.32       -7.44
# 299 2018-12-31 243.19     12  2018 209.54       18.07      -26.73

# %% [markdown]
# ## GB (Gradient Boosting)

# %%
# Just so we have the test and training data for the GB to choose the right features in the next cell
X_train
X_test
# Out:
#           date  calls  month  year  trend  resid_lags  resid_lag1  residual
# 0   1994-01-31 160.05      1  1994 172.17       -9.96        7.11    -12.12
# 1   1994-02-28 163.15      2  1994 172.30      -34.48      -12.12     -9.14
# 2   1994-03-31 173.05      3  1994 172.42       -8.11       -9.14      0.63
# 3   1994-04-30 158.49      4  1994 172.55      -28.58        0.63    -14.06
# 4   1994-05-31 162.24      5  1994 172.67      -18.62      -14.06    -10.43
# ..         ...    ...    ...   ...    ...         ...         ...       ...
# 195 2010-04-30 172.89      4  2010 196.54      -16.91       -7.49    -23.65
# 196 2010-05-31 188.69      5  2010 196.66       -4.54      -23.65     -7.97
# 197 2010-06-30 213.24      6  2010 196.79       24.75       -7.97     16.45
# 198 2010-07-31 221.73      7  2010 196.91       37.84       16.45     24.81
# 199 2010-08-31 217.57      8  2010 197.04       17.43       24.81     20.53
#
# [200 rows x 8 columns]
#           date  calls  month  year  trend  resid_lags  resid_lag1
# 200 2010-09-30 192.99      9  2010 197.16      -21.12       20.53
# 201 2010-10-31 168.57     10  2010 197.29      -11.96       -4.18
# 202 2010-11-30 180.52     11  2010 197.41       13.19      -28.72
# 203 2010-12-31 227.85     12  2010 197.54       28.36      -16.90
# 204 2011-01-31 167.04      1  2011 197.66       -8.77       30.31
# ..         ...    ...    ...   ...    ...         ...         ...
# 295 2018-08-31 222.64      8  2018 209.04       17.64       25.41
# 296 2018-09-30 186.75      9  2018 209.16        7.93       13.60
# 297 2018-10-31 201.84     10  2018 209.29       -8.42      -22.41
# 298 2018-11-30 182.68     11  2018 209.41      -16.32       -7.44
# 299 2018-12-31 243.19     12  2018 209.54       18.07      -26.73
#
# [100 rows x 7 columns]

# %%
# One shot training (i.e., no re-training)

# defining the model and parameters
gb = GradientBoostingRegressor(n_estimators = 100, max_depth = 6, min_samples_leaf = 2)

# Asking the model to fit the training data (features used: month, resid_lags, resid_lag1)
gb = gb.fit(X_train.drop(columns = ['date', 'calls', 'year', 'trend', 'residual']), y_train)

# Asking what the importance of features
gb.feature_importances_
# Out:
# array([0.11733802, 0.76207639, 0.12058559])

# %%
# Testing for one shot training
# Initialize the lists to store the percentage and absolute errors
gb_perc_error_list = []
gb_abs_error_list = []

# Make predictions using Gradient Boosting with a single run of train

y_test = X_test['calls'] # This is the final prediction that we will compare against

# Make predictions (residuals plus trend)
y_preds = gb.predict(X_test.drop(columns = ['date', 'calls', 'year', 'trend'])) + X_test['trend']

# Calculate percentage and absolute errors
perc_errors = np.abs(y_test-y_preds)/y_test
abs_errors = np.abs(y_test-y_preds)

# Store the percentage and absolute errors
gb_perc_error_list.append(perc_errors)
gb_abs_error_list.append(abs_errors)

# %%
# Print the percentage-error results
print('Mean absolute percentage error:', np.mean(gb_perc_error_list))
print('Median absolute percentage error:', np.median(gb_perc_error_list))
print('75th percentile of absolute percentage error:', np.percentile(gb_perc_error_list, 75))
print('90th percentile of absolute percentage error:', np.percentile(gb_perc_error_list, 90))
# Out:
# Mean absolute percentage error: 0.06495163041492194
# Median absolute percentage error: 0.04849335412895046
# 75th percentile of absolute percentage error: 0.08982519399607825
# 90th percentile of absolute percentage error: 0.14257778623695738

# %%
# Print the absolute error ratio results
print('Mean absolute error ratio:', np.mean(gb_abs_error_list)/avg_global)
print('Median absolute error ratio:', np.median(gb_abs_error_list)/avg_global)
print('75th percentile absolute error ratio:', np.percentile(gb_abs_error_list, 75)/avg_global)
print('90th percentile absolute error ratio:', np.percentile(gb_abs_error_list, 90)/avg_global)
# Out:
# Mean absolute error ratio: 0.06173269217775181
# Median absolute error ratio: 0.05052448021948054
# 75th percentile absolute error ratio: 0.08659466037357887
# 90th percentile absolute error ratio: 0.12639184364281197

# %%
# Comparing the forecasts against the actuals, graphically
plot_data = []
plot_data.append(go.Scatter(x= subset_data['date'][T+1:], y= subset_data['calls'][T+1:], name = 'calls'))
plot_data.append(go.Scatter(x= subset_data['date'][T+1:], y= y_preds[1:], name = 'GB', mode = 'markers'))
plot_data.append(go.Scatter(x= subset_data['date'][T+1:], y= es_preds_train[T+1:], name = 'ES', mode = 'markers'))
plot_data.append(go.Scatter(x= subset_data['date'][T+1:], y= ar_preds_train[T+1:], name = 'AR', mode = 'markers'))
layout = go.Layout(xaxis = dict(title='Date'), yaxis = dict(title= 'Calls made versus predicted'),
                   title = 'Monthly Calls Test Data vs. Predictions')
fig = go.Figure(data= plot_data, layout=layout)

plotly.offline.iplot(fig)

# %%
# Model forecasts versus actuals across 2 years
plot_data = []
plot_data.append(go.Scatter(x= subset_data['date'][T+1:T+25], y= subset_data['calls'][T+1:T+25], name = 'calls'))
plot_data.append(go.Scatter(x= subset_data['date'][T+1:T+25], y= y_preds[1:T+25], name = 'GB', mode = 'markers'))
plot_data.append(go.Scatter(x= subset_data['date'][T+1:T+25], y= es_preds_train[T+1:T+25], name = 'ES', mode = 'markers'))
plot_data.append(go.Scatter(x= subset_data['date'][T+1:T+25], y= ar_preds_train[T+1:T+25], name = 'AR', mode = 'markers'))
layout = go.Layout(xaxis = dict(title='Date'), yaxis = dict(title= 'Calls made versus predicted'),
                   title = 'Monthly Calls Test Data vs. Predictions')
fig = go.Figure(data= plot_data, layout=layout)

plotly.offline.iplot(fig)

# %% [markdown]
# ## XGBoost

# %% [markdown]
# ## Time Series Cross-Validation Function

# %%
def get_ts_cv_data(df, start_date, end_date, target_column='calls'):
    """
    Splits time series data into training and testing sets for cross-validation.

    Args:
        df (pd.DataFrame): The input DataFrame containing time series data.
        start_date (str): The start date for the test set (inclusive).
        end_date (str): The end date for the test set (exclusive).
        target_column (str): The name of the target column.

    Returns:
        tuple: X_train, X_test, y_train, y_test DataFrames/Series.
    """
    # Training data: all data before the start_date of the test set
    train_df = df[df['date'] < start_date]

    # Test data: data within the specified date range
    test_df = df[(df['date'] >= start_date) & (df['date'] < end_date)]

    # Features (X) and Target (y) for training and test sets
    X_train = train_df.drop(columns=[target_column, 'date'])
    y_train = train_df[target_column]

    X_test = test_df.drop(columns=[target_column, 'date'])
    y_test = test_df[target_column]

    return X_train, X_test, y_train, y_test

# %% [markdown]
# ### Demonstration of the Time Series Cross-Validation Function

# %%
# Example usage:
# Let's use 'subset_data' and define a test period, e.g., for January 2017.
# Note: This example assumes 'subset_data' already has 'month', 'year', 'trend', 'resid_lags', 'resid_lag1' as features.
# If you want to use the residual as the target, you'd adjust `target_column` and the `y_train`, `y_test` definitions accordingly.

# --- Start of robustness block: Ensure 'subset_data' and its features are initialized ---
import pandas as pd
from IPython.display import display # For displaying DataFrames
import os

# Define the expected file path in the Colab environment
file_path = 'calls_data.csv' # Assuming the file is in the root /content/ directory

# Check if subset_data is defined and has required columns
if 'subset_data' not in globals() or not isinstance(subset_data, pd.DataFrame) or \
   'trend' not in subset_data.columns or 'resid_lags' not in subset_data.columns or 'resid_lag1' not in subset_data.columns:
    print("Initializing 'calls_df' and 'subset_data' with required features for the example...")

    try:
        # Re-fetch data from the CSV file
        calls_df = pd.read_csv(file_path, parse_dates=['date'])
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' was not found.")
        print("Please upload 'calls_data.csv' to your Colab environment's root directory (e.g., /content/) or update the 'file_path' variable with the correct location.")
        # You can add further error handling here, e.g., exit or raise
        raise # Re-raise the error after printing instructions

    # Subset data to only include 300 data points (most recent) (from cell 4e2580ca)
    subset_data = calls_df[calls_df['date'] > '1994-01-01'].reset_index(drop = True)

    # Add month and year features (from cell 24a98cac)
    subset_data['month'] = subset_data['date'].dt.month
    subset_data['year'] = subset_data['date'].dt.year

    # Add month, year, and trend features to calls_df (from cell be05f9ff)
    # These constants are derived from previous cells (5355f0b3 and 5027b4cb)
    trend_slope = 1.4995
    trend_intercept = -2817.955
    calls_df['month'] = calls_df['date'].dt.month
    calls_df['year'] = calls_df['date'].dt.year
    calls_df['trend'] = trend_intercept + trend_slope * (calls_df['year'] + calls_df['month']/12)

    # Calculate trend for subset_data (from cell 5027b4cb)
    subset_data['trend'] = trend_intercept + trend_slope * (subset_data['year'] + subset_data['month']/12)

    # Define seasonal_periods if not already defined (from cell 7b6e61de)
    seasonal_periods = 12

    # Residuals (de-trending) and shifting them to get lags (from cell aa99ef05)
    # Creating full residual series first to ensure correct alignment for lags
    full_residuals = calls_df['calls'] - calls_df['trend']
    subset_data['resid_lags'] = full_residuals.shift(periods=seasonal_periods).loc[calls_df['date'].isin(subset_data['date'])].reset_index(drop=True)
    subset_data['resid_lag1'] = full_residuals.shift(periods=1).loc[calls_df['date'].isin(subset_data['date'])].reset_index(drop=True)
# --- End of robustness block ---

# For this demonstration, let's re-create the 'residual' column in `subset_data` if it's not present
# and ensure relevant features are available.
if 'residual' not in subset_data.columns:
    subset_data['residual'] = subset_data['calls'] - subset_data['trend']

# Define the date range for one cross-validation fold
# Let's say we want to train on data before '2017-01-01' and test for Jan-Mar 2017
start_test_date = '2017-01-01'
end_test_date = '2017-04-01' # Exclusive, so up to March 31, 2017

X_train_cv, X_test_cv, y_train_cv, y_test_cv = get_ts_cv_data(
    subset_data,
    start_test_date,
    end_test_date,
    target_column='calls' # You can change this to 'residual' if you want to predict residuals
)

print("X_train_cv head:")
display(X_train_cv.head())
print("X_test_cv head:")
display(X_test_cv.head())
print("y_train_cv head:")
display(y_train_cv.head())
print("y_test_cv head:")
display(y_test_cv.head())

print(f"\nShape of X_train_cv: {X_train_cv.shape}")
print(f"Shape of X_test_cv: {X_test_cv.shape}")
print(f"Shape of y_train_cv: {y_train_cv.shape}")
print(f"Shape of y_test_cv: {y_test_cv.shape}")
# Out:
# Initializing 'calls_df' and 'subset_data' with required features for the example...
# Error: The file 'calls_data.csv' was not found.
# Please upload 'calls_data.csv' to your Colab environment's root directory (e.g., /content/) or update the 'file_path' variable with the correct location.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2086/3200726461.py in <cell line: 0>()
#      19     try:
#      20         # Re-fetch data from the CSV file
# ---> 21         calls_df = pd.read_csv(file_path, parse_dates=['date'])
#      22     except FileNotFoundError:
#      23         print(f"Error: The file '{file_path}' was not found.")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'calls_data.csv'

# %%
# If we simply use the parameters without hyper parameter tuning
# One shot training

# Define the XGBoost regressor with specific hyperparameters
model = XGBRegressor(
    n_estimators=100,
    max_depth=6,
    learning_rate=0.1,
    subsample=1.0,
    colsample_bytree=1.0,
    objective='reg:squarederror',
    random_state=42
)

# Asking the model to fit the training data
model.fit(X_train.drop(columns = ['date', 'calls', 'year', 'trend', 'residual']), y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ### Loading Data from Google Drive
#
# To load data from Google Drive in Colab, you need to first mount your Google Drive to the Colab environment. Then, you can access your files using their full path within the mounted Drive.
#
# 1.  **Mount Google Drive:** Run the following code cell to mount your Drive. You'll be prompted to authorize Colab to access your Google Drive.
# 2.  **Find the File Path:** Once mounted, your Drive will be accessible at `/content/drive/My Drive/`. You can navigate to your file in the Colab file browser (left sidebar -> folder icon) to copy its path, or manually construct it (e.g., `/content/drive/My Drive/your_folder/your_file.csv`).
# 3.  **Load the File:** Use a library like `pandas` with the full file path.

# %%
from google.colab import drive
import pandas as pd

# 1. Mount Google Drive
drive.mount('/content/drive')

# 2. Specify the path to your CSV file on Google Drive
# Replace 'path/to/your/folder/your_file.csv' with the actual path to your file
google_drive_file_path = '/content/drive/My Drive/calls_data.csv' # Example path

# 3. Load the CSV file into a pandas DataFrame
try:
    df_from_drive = pd.read_csv(google_drive_file_path, parse_dates=['date'])
    print("Successfully loaded data from Google Drive!")
    display(df_from_drive.head())
except FileNotFoundError:
    print(f"Error: The file '{google_drive_file_path}' was not found.")
    print("Please ensure the file exists at the specified path in your Google Drive and you have granted access.")
except Exception as e:
    print(f"An error occurred while loading the file: {e}")
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_2086/2982862074.py in <cell line: 0>()
#       3
#       4 # 1. Mount Google Drive
# ----> 5 drive.mount('/content/drive')
#       6
#       7 # 2. Specify the path to your CSV file on Google Drive
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
# One shot training
# Initialize the lists to store the percentage and absolute errors
xgb_perc_error_list = []
xgb_abs_error_list = []

# Make predictions using Xtreme Gradient Boosting with a single run of train

y_test = X_test['calls']

# Make predictions
y_preds = model.predict(X_test.drop(columns = ['date', 'calls', 'year', 'trend'])) + X_test['trend']

# Calculate percentage and absolute errors
perc_errors = np.abs(y_test-y_preds)/y_test
abs_errors = np.abs(y_test-y_preds)

# Store the percentage and absolute errors
xgb_perc_error_list.append(perc_errors)
xgb_abs_error_list.append(abs_errors)

# %%
# Print the percentage-error results
print('Mean absolute percentage error:', np.mean(xgb_perc_error_list, axis = 1))
print('Median absolute percentage error:', np.median(xgb_perc_error_list, axis = 1))
print('75th percentile of absolute percentage error:', np.percentile(xgb_perc_error_list, 75, axis = 1))
print('90th percentile of absolute percentage error:', np.percentile(xgb_perc_error_list, 90, axis = 1))
# Out:
# Mean absolute percentage error: [0.06465959]
# Median absolute percentage error: [0.05525418]
# 75th percentile of absolute percentage error: [0.08962071]
# 90th percentile of absolute percentage error: [0.13615874]

# %%
# Print the absolute error ratio results
print('Mean absolute error ratio:', np.mean(xgb_abs_error_list, axis = 1)/avg_global)
print('Median absolute error ratio:', np.median(xgb_abs_error_list, axis = 1)/avg_global)
print('75th percentile absolute error ratio:', np.percentile(xgb_abs_error_list, 75, axis = 1)/avg_global)
print('90th percentile absolute error ratio:', np.percentile(xgb_abs_error_list, 90, axis = 1)/avg_global)
# Out:
# Mean absolute error ratio: [0.06152881]
# Median absolute error ratio: [0.05124117]
# 75th percentile absolute error ratio: [0.08775255]
# 90th percentile absolute error ratio: [0.1307467]
